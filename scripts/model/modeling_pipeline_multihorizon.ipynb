# %% [markdown]
# # So sanh model du bao gia ca phe Robusta noi dia (theo ngay)
#
# **Muc tieu:** du bao muc gia `Gia_target` (TB Dak Lak + Lam Dong, VND/kg) theo ngay, chi dung **ML co dien** (khong deep learning).
#
# **Du lieu:** `gia_cafe_master.csv` — 1.566 ngay lam viec (2020-2025), 18 feature (tu hoi quy gia + lich + London/ty gia + dau diesel + xuat khau + thoi tiet/ONI).
#
# **Pipeline:**
# 1. Nap & chuan bi du lieu (xu ly NaN, chong ro ri)
# 2. Chon khung target: `level` (muc gia) hoac `delta` (thay doi) — delta giup mo hinh cay ngoai suy duoc tren dinh gia ky luc
# 3. Metric: MAE, RMSE, sMAPE, MASE, Directional Accuracy
# 4. Walk-forward CV (cua so mo rong)
# 5. Bo model: Naive, ARIMAX, Ridge/Lasso/ElasticNet, RandomForest, XGBoost, LightGBM, SVR, kNN
# 6. Bang ket qua + truc quan + feature importance + kiem dinh Diebold-Mariano
#
# > Tat ca model deu duoc danh gia tren **muc gia** de so sanh cong bang.

# %%
# Neu chay tren Colab/may chua co thu vien, bo comment dong duoi:
# !pip install scikit-learn scipy statsmodels xgboost lightgbm

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

from sklearn.linear_model import Ridge, Lasso, ElasticNet
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

HAS_XGB = True
try:
    from xgboost import XGBRegressor
except Exception:
    HAS_XGB = False

HAS_LGB = True
try:
    from lightgbm import LGBMRegressor
except Exception:
    HAS_LGB = False

HAS_SM = True
try:
    from statsmodels.tsa.statespace.sarimax import SARIMAX
except Exception:
    HAS_SM = False

plt.rcParams['figure.figsize'] = (12, 5)
print('xgboost:', HAS_XGB, '| lightgbm:', HAS_LGB, '| statsmodels:', HAS_SM)

import sys
sys.path.insert(0, r"E:\\FPT\\AI\\SEM8_AI\\DAP391m\\project\\CofPred\\scripts\\model")  # noi de export_preds.py
from export_preds import save_preds
PREDS_DIR = r"E:\\FPT\\AI\\SEM8_AI\\DAP391m\\project\\CofPred\\results\\preds"
# Out:
# xgboost: True | lightgbm: True | statsmodels: True

# %% [markdown]
# ## 1. Nap du lieu

# %%
CSV_PATH = 'E:\FPT\AI\SEM8_AI\DAP391m\project\CofPred\data\processed\gia_cafe_master_full.csv'
df = pd.read_csv(CSV_PATH, parse_dates=['Ngay']).sort_values('Ngay').reset_index(drop=True)
df = df.set_index('Ngay')
print('Shape:', df.shape)
print('Khoang thoi gian:', df.index.min().date(), '->', df.index.max().date())

# --- KIEM TRA CHONG NHAM FILE CU (bi ro ri) ---
n_weekend = int((df.index.dayofweek >= 5).sum())
if n_weekend > 0:
    print(f"\n[CANH BAO] Co {n_weekend} dong cuoi tuan (T7/CN) -> day la MASTER CU bi ro ri!")
    print("           Hay chay lai: gia_taynguyen.py + 41_build_master_full.py de ghi de file.")
    print("           File dung phai co ~1566 dong, 0 dong cuoi tuan.")
else:
    print(f"\n[OK] Khong co ngay cuoi tuan. So dong: {len(df)} (ky vong ~1566).")
df.head()
# Out:
# Shape: (1566, 26)
# Khoang thoi gian: 2020-01-01 -> 2025-12-31
#
# [OK] Khong co ngay cuoi tuan. So dong: 1566 (ky vong ~1566).
#             Gia_target  outlier_flag  target_lag1  target_lag2  target_lag3  \
# Ngay
# 2020-01-01     32319.5             0          NaN          NaN          NaN
# 2020-01-02     32319.5             0      32319.5          NaN          NaN
# 2020-01-03     32269.5             0      32319.5      32319.5          NaN
# 2020-01-06     32460.5             0      32269.5      32319.5      32319.5
# 2020-01-07     32127.0             0      32460.5      32269.5      32319.5
#
#             target_ret_lag1           MA5  MA10       std5  dayofweek  ...  \
# Ngay                                                                   ...
# 2020-01-01              NaN           NaN   NaN        NaN          2  ...
# 2020-01-02              NaN           NaN   NaN        NaN          3  ...
# 2020-01-03         0.000000           NaN   NaN        NaN          4  ...
# 2020-01-06        -0.001547  32302.833333   NaN  28.867513          0  ...
# 2020-01-07         0.005919  32342.250000   NaN  82.281529          1  ...
#
#               rain_90d   oni  waterbal_90d  Luong_lag1m  dongia_lag1m  \
# Ngay
# 2020-01-01  203.479996  0.58   -142.271622         87.5   1800.800000
# 2020-01-02  188.599996  0.58   -157.761064         87.5   1800.800000
# 2020-01-03  180.959996  0.58   -166.691354         87.5   1800.800000
# 2020-01-06  176.779996  0.58   -170.171394        112.9   1738.352524
# 2020-01-07  175.179996  0.58   -171.686609        112.9   1738.352524
#
#             dongia_ret_lag1m  area_tn    prod_tn  yield_tn  tonkho_tan
# Ngay
# 2020-01-01         -0.014087    618.0  1511494.4  2.445784     33360.0
# 2020-01-02         -0.014087    618.0  1511494.4  2.445784     33360.0
# 2020-01-03         -0.014087    618.0  1511494.4  2.445784     33360.0
# 2020-01-06         -0.034678    618.0  1511494.4  2.445784     33360.0
# 2020-01-07         -0.034678    618.0  1511494.4  2.445784     33360.0
#
# [5 rows x 26 columns]

# %% [markdown]
# ## 2. Chuan bi feature / target
#
# Bo cac cot de gay **ro ri** (gia thanh phan Dak Lak/Lam Dong = chinh la target) va xu ly NaN (ngay khuyet gia + warmup cua lag/rolling).

# %%
TARGET = 'Gia_target'

# Bo 24 feature day du khop mo hinh huong 66,1% trong bao cao
AR = ['target_lag1','target_lag2','target_lag3','target_ret_lag1',
      'MA5','MA10','std5','dayofweek','month']
EXO = ['london_vnd_kg_lag1','usdvnd_lag1','diesel','diesel_chg_1m','diesel_chg_3m',
       'Luong_lag1m','rain_90d','oni','waterbal_90d']
SUPPLY = ['area_tn','prod_tn','yield_tn','tonkho_tan','dongia_lag1m','dongia_ret_lag1m']
WANT = AR + EXO + SUPPLY

# Chi giu cot thuc su co trong file; canh bao cot thieu
FEATURES = [c for c in WANT if c in df.columns]
missing = [c for c in WANT if c not in df.columns]
if missing:
    print('[CANH BAO] Thieu', len(missing), 'feature trong file:', missing)
    print('           -> Hay chay lai 41_build_master_full.py de sinh du 24 feature.')
print('Dung', len(FEATURES), 'feature:', FEATURES)

data = df[[TARGET] + FEATURES].copy()

# prev_price (gia ngay truoc) dung cho Naive va delta mode; KHONG nam trong FEATURES
prev_price = data[TARGET].shift(1).rename('prev_price')
data['prev_price'] = prev_price

before = len(data)
data = data.dropna(subset=[TARGET] + FEATURES + ['prev_price'])
print('Bo', before - len(data), 'dong NaN (warm-up + dut bao gia) ->', len(data), 'dong dung duoc')

X = data[FEATURES].copy()
prev_series = data['prev_price'].copy()
y_level = data[TARGET].copy()
print('X:', X.shape, '| y:', y_level.shape)
# Out:
# Dung 24 feature: ['target_lag1', 'target_lag2', 'target_lag3', 'target_ret_lag1', 'MA5', 'MA10', 'std5', 'dayofweek', 'month', 'london_vnd_kg_lag1', 'usdvnd_lag1', 'diesel', 'diesel_chg_1m', 'diesel_chg_3m', 'Luong_lag1m', 'rain_90d', 'oni', 'waterbal_90d', 'area_tn', 'prod_tn', 'yield_tn', 'tonkho_tan', 'dongia_lag1m', 'dongia_ret_lag1m']
# Bo 50 dong NaN (warm-up + dut bao gia) -> 1516 dong dung duoc
# X: (1516, 24) | y: (1516,)

# %% [markdown]
# ## 3. Khung target: `level` vs `delta`
#
# Gia tang ky luc (32k -> 97k VND/kg). **Mo hinh cay khong ngoai suy duoc** (khong du bao cao hon max da thay khi train).
#
# - `level`: du bao truc tiep muc gia.
# - `delta`: du bao `gia - target_lag1` roi cong lai `target_lag1` -> bo qua tran, hop voi chuoi co xu huong manh.
#
# Doi `TARGET_MODE` de thu nghiem.

# %%
# === CHON CHAN TROI DU BAO ===
# HORIZON = so ngay LAM VIEC du bao toi:
#   1  = ngay mai        5  = 1 tuan        10 = 2 tuan
#   21 = 1 thang         63 = 1 quy
# Doi gia tri nay roi chay lai tu cell nay tro xuong de co ket qua tung chan troi.
HORIZON = 1
TARGET_MODE = 'level'   # 'delta' (du bao thay doi gia) hoac 'level'

_HN = {1:'1 ngay (ngay mai)',5:'1 tuan',10:'2 tuan',21:'1 thang',63:'1 quy'}
HORIZON_NAME = _HN.get(HORIZON, f'{HORIZON} ngay lam viec')

price  = y_level.copy()            # gia(t) - da biet tai thoi diem t
future = price.shift(-HORIZON)     # gia(t+h) - dai luong CAN du bao
anchor = price.copy()              # moc hien tai = gia(t)

print(f'HORIZON = {HORIZON} ngay lam viec ({HORIZON_NAME}) | TARGET_MODE = {TARGET_MODE}')
print(f'Du bao gia(t+{HORIZON}) tu thong tin biet den ngay t (KHONG phai ngay mai).')
# Out:
# HORIZON = 1 ngay lam viec (1 ngay (ngay mai)) | TARGET_MODE = level
# Du bao gia(t+1) tu thong tin biet den ngay t (KHONG phai ngay mai).

# %% [markdown]
# ## 4. Metric danh gia

# %%
def mae(a, p):  return float(np.mean(np.abs(a - p)))
def rmse(a, p): return float(np.sqrt(np.mean((a - p) ** 2)))

def smape(a, p):
    denom = (np.abs(a) + np.abs(p)) / 2.0
    return float(np.mean(np.abs(a - p) / np.where(denom == 0, np.nan, denom)) * 100)

def mase(a, p, y_train):
    # SUA: mau so = MAE naive tren PHAN TRAIN BAN DAU (khong gom test).
    # Ban cu dung toan chuoi (ca test) -> lech chuan MASE.
    d = np.mean(np.abs(np.diff(y_train)))
    return float(mae(a, p) / d)

def directional_accuracy(a, p, prev):
    # ti le du bao dung huong tang/giam so voi ngay truoc
    return float(np.mean(np.sign(a - prev) == np.sign(p - prev)) * 100)

# %% [markdown]
# ## 5. Walk-forward CV (cua so mo rong)
#
# Re-fit moi `STEP` ngay (mac dinh 21 ~ 1 thang) tren toan bo du lieu qua khu, du bao khoi tiep theo. Khong bao gio dung du lieu tuong lai.

# %%
def walk_forward(make_model, X, future, anchor, initial=0.6, step=5, horizon=5, mode='delta'):
    # Walk-forward expanding window. Tai moi diem quyet dinh d:
    #   - du bao gia(t+h) = gia(d+horizon)
    #   - TRAIN chi gom cac cap (t, t+h) da hoan thanh: t+h <= d  <=>  t <= d-horizon
    #     -> nhan huan luyen khong nhin tuong lai.
    n = len(X)
    start = int(n * initial)
    recs = []
    for d in range(start, n - horizon, step):
        tr = d - horizon + 1                 # so dong train hop le (t = 0..d-horizon)
        if tr <= 20:
            continue
        Xtr = X.iloc[:tr]
        ytr = (future - anchor).iloc[:tr] if mode == 'delta' else future.iloc[:tr]
        m = make_model(); m.fit(Xtr, ytr)
        raw = float(m.predict(X.iloc[[d]])[0])
        pred = float(anchor.iloc[d]) + raw if mode == 'delta' else raw
        recs.append((X.index[d], float(future.iloc[d]), float(anchor.iloc[d]), pred))
    return pd.DataFrame(recs, columns=['Ngay','y_true','anchor','pred']).set_index('Ngay')

# %% [markdown]
# ## 6. Dinh nghia model

# %%
def make_models():
    m = {}
    m['Ridge']      = lambda: Pipeline([('sc', StandardScaler()), ('m', Ridge(alpha=1.0))])
    m['Lasso']      = lambda: Pipeline([('sc', StandardScaler()), ('m', Lasso(alpha=0.001, max_iter=10000))])
    m['ElasticNet'] = lambda: Pipeline([('sc', StandardScaler()), ('m', ElasticNet(alpha=0.001, l1_ratio=0.5, max_iter=10000))])
    m['RandomForest'] = lambda: RandomForestRegressor(n_estimators=400, min_samples_leaf=2, n_jobs=-1, random_state=42)
    if HAS_XGB:
        m['XGBoost'] = lambda: XGBRegressor(n_estimators=500, learning_rate=0.03, max_depth=4,
                                            subsample=0.8, colsample_bytree=0.8, random_state=42, n_jobs=-1)
    if HAS_LGB:
        m['LightGBM'] = lambda: LGBMRegressor(n_estimators=600, learning_rate=0.03, num_leaves=31,
                                              subsample=0.8, colsample_bytree=0.8, random_state=42, n_jobs=-1, verbose=-1)
    m['SVR'] = lambda: Pipeline([('sc', StandardScaler()), ('m', SVR(C=10.0, epsilon=0.1, kernel='rbf'))])
    m['kNN'] = lambda: Pipeline([('sc', StandardScaler()), ('m', KNeighborsRegressor(n_neighbors=10))])
    return m

MODELS = make_models()
print('Models:', list(MODELS.keys()))
# Out:
# Models: ['Ridge', 'Lasso', 'ElasticNet', 'RandomForest', 'XGBoost', 'LightGBM', 'SVR', 'kNN']

# %% [markdown]
# ## 7. Baseline: Naive + ARIMAX

# %%
INITIAL, STEP = 0.6, 5      # STEP = nhip lay diem test (giam chong lap), KHONG phai chan troi
results_blocks = {}
n = len(X); start = int(n * INITIAL)

# --- Naive (random walk): du bao gia(t+h) = gia(t) hien tai (khong doi) ---
naive_rows = []
for d in range(start, n - HORIZON, STEP):
    naive_rows.append((X.index[d], float(future.iloc[d]), float(anchor.iloc[d]), float(anchor.iloc[d])))
naive_df = pd.DataFrame(naive_rows, columns=['Ngay','y_true','anchor','pred']).set_index('Ngay')
results_blocks['Naive'] = naive_df

EVAL    = naive_df.index                 # truc thoi gian danh gia chung
y_true  = naive_df['y_true'].values      # = gia(t+h) thuc te
anchor_eval = naive_df['anchor'].values  # = gia(t)
print(f'So diem test (chan troi {HORIZON_NAME}): {len(EVAL)}')

# --- ARIMAX(1,1,1): fit den ngay t, du bao h buoc, lay buoc thu h ---
# Exog giu co dinh = gia tri ngay t (tranh dung exog tuong lai -> khong look-ahead).
if HAS_SM:
    exog_cols = [c for c in EXO if c in FEATURES]
    arx_rows = []
    for d in range(start, n - HORIZON, STEP):
        tr = d + 1
        try:
            r = SARIMAX(price.iloc[:tr], exog=X[exog_cols].iloc[:tr], order=(1,1,1),
                        enforce_stationarity=False, enforce_invertibility=False).fit(disp=False)
            exog_future = np.tile(X[exog_cols].iloc[[d]].values, (HORIZON, 1))
            fc = np.asarray(r.forecast(steps=HORIZON, exog=exog_future))
            pred = float(fc[-1])
        except Exception:
            pred = float(anchor.iloc[d])
        arx_rows.append((X.index[d], float(future.iloc[d]), float(anchor.iloc[d]), pred))
    results_blocks['ARIMAX(1,1,1)'] = pd.DataFrame(
        arx_rows, columns=['Ngay','y_true','anchor','pred']).set_index('Ngay')
else:
    print('Bo qua ARIMAX (chua co statsmodels)')
# Out:
# So diem test (chan troi 1 ngay (ngay mai)): 122
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# ...
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# ## 8. Chay tat ca model ML

# %%
for name, factory in MODELS.items():
    results_blocks[name] = walk_forward(
        factory, X, future, anchor,
        initial=INITIAL, step=STEP, horizon=HORIZON, mode=TARGET_MODE)
print('Da chay:', list(results_blocks.keys()))
# Out:
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.474e+08, tolerance: 5.288e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.495e+08, tolerance: 5.640e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.502e+08, tolerance: 5.985e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.510e+08, tolerance: 6.351e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.508e+08, tolerance: 6.736e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.500e+08, tolerance: 7.115e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.526e+08, tolerance: 7.488e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.572e+08, tolerance: 7.794e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.586e+08, tolerance: 8.109e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.594e+08, tolerance: 8.449e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.606e+08, tolerance: 8.765e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.641e+08, tolerance: 9.114e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.655e+08, tolerance: 9.465e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.655e+08, tolerance: 9.799e+06
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.682e+08, tolerance: 1.008e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.685e+08, tolerance: 1.034e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.115e+08, tolerance: 1.053e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.137e+08, tolerance: 1.070e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.158e+08, tolerance: 1.084e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.174e+08, tolerance: 1.098e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.223e+08, tolerance: 1.114e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.230e+08, tolerance: 1.127e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.235e+08, tolerance: 1.142e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.241e+08, tolerance: 1.160e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.338e+08, tolerance: 1.188e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.362e+08, tolerance: 1.222e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.405e+08, tolerance: 1.257e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.437e+08, tolerance: 1.290e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+08, tolerance: 1.331e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.513e+08, tolerance: 1.376e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.532e+08, tolerance: 1.430e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.558e+08, tolerance: 1.494e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.561e+08, tolerance: 1.559e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.654e+08, tolerance: 1.625e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.664e+08, tolerance: 1.700e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.705e+08, tolerance: 1.786e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.794e+08, tolerance: 1.891e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.806e+08, tolerance: 2.006e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.818e+08, tolerance: 2.134e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.840e+08, tolerance: 2.279e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.904e+08, tolerance: 2.448e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.068e+08, tolerance: 2.650e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.326e+08, tolerance: 2.940e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.422e+08, tolerance: 3.319e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.668e+08, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.134e+09, tolerance: 3.823e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.184e+09, tolerance: 3.977e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.213e+09, tolerance: 4.197e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.241e+09, tolerance: 4.476e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e+09, tolerance: 4.770e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.264e+09, tolerance: 5.045e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.269e+09, tolerance: 5.306e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.285e+09, tolerance: 5.572e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.291e+09, tolerance: 5.850e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.314e+09, tolerance: 6.162e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.322e+09, tolerance: 6.465e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.333e+09, tolerance: 6.745e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.336e+09, tolerance: 7.012e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.340e+09, tolerance: 7.265e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.346e+09, tolerance: 7.494e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.349e+09, tolerance: 7.729e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.416e+09, tolerance: 7.959e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.466e+09, tolerance: 8.181e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.477e+09, tolerance: 8.414e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485e+09, tolerance: 8.657e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.515e+09, tolerance: 8.883e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.519e+09, tolerance: 9.071e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.523e+09, tolerance: 9.249e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.527e+09, tolerance: 9.412e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.529e+09, tolerance: 9.566e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.536e+09, tolerance: 9.736e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.552e+09, tolerance: 9.936e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.566e+09, tolerance: 1.021e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.008e+09, tolerance: 1.040e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.012e+09, tolerance: 1.064e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.021e+09, tolerance: 1.087e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.030e+09, tolerance: 1.109e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.058e+09, tolerance: 1.130e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.076e+09, tolerance: 1.155e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.130e+09, tolerance: 1.182e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.148e+09, tolerance: 1.211e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.163e+09, tolerance: 1.239e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.184e+09, tolerance: 1.267e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.198e+09, tolerance: 1.295e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.201e+09, tolerance: 1.324e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.204e+09, tolerance: 1.354e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.207e+09, tolerance: 1.382e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.315e+09, tolerance: 1.402e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.387e+09, tolerance: 1.428e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.412e+09, tolerance: 1.454e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.419e+09, tolerance: 1.480e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.446e+09, tolerance: 1.503e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.451e+09, tolerance: 1.526e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.456e+09, tolerance: 1.547e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.457e+09, tolerance: 1.566e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.464e+09, tolerance: 1.582e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.471e+09, tolerance: 1.596e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.478e+09, tolerance: 1.608e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.529e+09, tolerance: 1.614e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.547e+09, tolerance: 1.620e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.680e+09, tolerance: 1.626e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.775e+09, tolerance: 1.631e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.825e+09, tolerance: 1.637e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.864e+09, tolerance: 1.643e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.899e+09, tolerance: 1.651e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.981e+09, tolerance: 1.663e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.017e+09, tolerance: 1.680e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.043e+09, tolerance: 1.699e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.083e+09, tolerance: 1.716e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.176e+09, tolerance: 1.731e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.183e+09, tolerance: 1.744e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.190e+09, tolerance: 1.757e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.198e+09, tolerance: 1.771e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.200e+09, tolerance: 1.786e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.206e+09, tolerance: 1.801e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.277e+09, tolerance: 1.813e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.320e+09, tolerance: 1.826e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.339e+09, tolerance: 1.837e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.380e+09, tolerance: 1.844e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.410e+09, tolerance: 1.851e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.451e+09, tolerance: 1.854e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.462e+09, tolerance: 1.860e+08
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.993e+07, tolerance: 2.650e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.554e+08, tolerance: 2.940e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.082e+08, tolerance: 3.319e+07
#   model = cd_fast.enet_coordinate_descent(
# c:\Users\quangbeone\AppData\Local\miniconda3\envs\cofpred\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:716: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.918e+08, tolerance: 3.684e+07
#   model = cd_fast.enet_coordinate_descent(
# Da chay: ['Naive', 'ARIMAX(1,1,1)', 'Ridge', 'Lasso', 'ElasticNet', 'RandomForest', 'XGBoost', 'LightGBM', 'SVR', 'kNN']

# %% [markdown]
# ## 9. Bang ket qua

# %%
# MASE: mau so = MAE naive 1-buoc tren PHAN TRAIN BAN DAU (khong gom test)
y_train_mase = price.values[:int(len(price) * INITIAL)]
rows = []
for name, blk in results_blocks.items():
    b = blk.reindex(EVAL)
    p = b['pred'].values.astype(float)
    a = b['y_true'].values.astype(float)
    anc = b['anchor'].values.astype(float)
    msk = np.isfinite(p) & np.isfinite(a)
    rows.append({
        'Model': name,
        'MAE':   mae(a[msk], p[msk]),
        'RMSE':  rmse(a[msk], p[msk]),
        'sMAPE(%)': smape(a[msk], p[msk]),
        'MASE':  mase(a[msk], p[msk], y_train_mase),
        'DA(%)': directional_accuracy(a[msk], p[msk], anc[msk]),
    })
res = pd.DataFrame(rows).sort_values('RMSE').reset_index(drop=True)
os.makedirs("E:\\FPT\AI\\SEM8_AI\\DAP391m\\project\CofPred\\results\\ML_model", exist_ok=True)
res.to_csv(f'E:\\FPT\\AI\\SEM8_AI\\DAP391m\\project\\CofPred\\results\\ML_model\\model_comparison_h{HORIZON}_{TARGET_MODE}.csv', index=False)
print(f'=== Chan troi {HORIZON_NAME} (h={HORIZON}, n={len(EVAL)} diem test) ===')
res
# Out:
# === Chan troi 1 ngay (ngay mai) (h=1, n=122 diem test) ===
#            Model           MAE          RMSE   sMAPE(%)        MASE      DA(%)
# 0          Naive   1567.343443   3811.219328   1.459466    5.228004   9.836066
# 1  ARIMAX(1,1,1)   1604.822545   3886.886521   1.496477    5.353018  46.721311
# 2        XGBoost   2125.601140   4108.685893   2.035819    7.090119  45.081967
# 3       LightGBM   2380.248388   4316.023010   2.312732    7.939516  45.901639
# 4     ElasticNet   2345.243581   4526.814266   2.206616    7.822754  40.983607
# 5          Ridge   2349.394678   4529.744052   2.209962    7.836600  40.163934
# 6          Lasso   2326.005201   4546.513690   2.183661    7.758583  43.442623
# 7   RandomForest   2358.546107   4558.242295   2.260434    7.867126  45.901639
# 8            kNN   4533.875820   6831.101195   4.403273   15.123118  49.180328
# 9            SVR  58985.647441  63431.421033  78.558104  196.751509  44.262295

# %%
from export_preds import save_preds   # đã set path ở trên
for name, blk in results_blocks.items():
    b = blk.reindex(EVAL).dropna(subset=['pred'])
    save_preds(name, HORIZON, b.index, b['y_true'], b['pred'],
               anchor=b['anchor'], outdir=PREDS_DIR)

# %% [markdown]
# ## 10. Truc quan du bao (model tot nhat)

# %%
best = res.iloc[0]['Model']
bb = results_blocks[best].reindex(EVAL)
nn = results_blocks['Naive'].reindex(EVAL)
plt.figure(figsize=(13,5))
plt.plot(EVAL, y_true,        label='Thuc te gia(t+h)', color='black', lw=1.2)
plt.plot(EVAL, bb['pred'],    label='Du bao (' + best + ')', color='tab:red', lw=1)
plt.plot(EVAL, nn['pred'],    label='Naive', color='tab:blue', lw=0.7, alpha=0.6)
plt.title(f'Du bao vs thuc te - {best} - chan troi {HORIZON_NAME} (mode={TARGET_MODE})')
plt.ylabel('Gia (VND/kg)'); plt.legend(); plt.tight_layout()
plt.savefig(f'E:\\FPT\\AI\\SEM8_AI\\DAP391m\\project\\CofPred\\results\\ML_model\\forecast_best_h{HORIZON}_{TARGET_MODE}.png', dpi=120)
plt.show()

# %% [markdown]
# ## 11. Feature importance

# %%
# LUU Y: cell nay fit tren TOAN BO du lieu -> chi de XEM do quan trong feature,
# KHONG dung de chon feature (selection bias).
tree_pref = [m for m in ['LightGBM','XGBoost','RandomForest'] if m in MODELS]
imp_name = next((c for c in tree_pref if c in res['Model'].values), 'RandomForest')

yfull = (future - anchor) if TARGET_MODE == 'delta' else future
msk = future.notna()
mdl = MODELS[imp_name]()
mdl.fit(X[msk], yfull[msk])
imp = getattr(mdl, 'feature_importances_', None)
if imp is not None:
    fi = pd.Series(imp, index=FEATURES).sort_values()
    fi.plot(kind='barh', figsize=(8,7), title=f'Feature importance - {imp_name} (h={HORIZON})')
    plt.tight_layout(); plt.savefig(f'E:\\FPT\\AI\\SEM8_AI\\DAP391m\\project\\CofPred\\results\\ML_model\\feature_importance_h{HORIZON}_{TARGET_MODE}.png', dpi=120); plt.show()
    print(fi.sort_values(ascending=False))
else:
    print('Model', imp_name, 'khong co feature_importances_')
# Out:
# std5                  1882
# london_vnd_kg_lag1    1795
# target_lag1           1631
# target_ret_lag1       1471
# usdvnd_lag1           1284
# target_lag3           1225
# MA10                  1203
# MA5                    962
# target_lag2            952
# rain_90d               828
# waterbal_90d           783
# diesel_chg_1m          731
# diesel_chg_3m          578
# diesel                 576
# dongia_lag1m           538
# dayofweek              384
# dongia_ret_lag1m       371
# Luong_lag1m            287
# oni                    272
# month                  168
# area_tn                 34
# tonkho_tan              30
# prod_tn                 11
# yield_tn                 4
# dtype: int32

# %% [markdown]
# ## 12. Kiem dinh Diebold-Mariano (vs Naive)
#
# |DM| > 1.96 => chenh lech sai so co y nghia thong ke 5%.

# %%
def diebold_mariano(y, p1, p2, h=1):
    # loss = squared error; DM>0: p1 te hon p2. HAC/Newey-West lag = h-1.
    d = (y - p1) ** 2 - (y - p2) ** 2
    d = d[np.isfinite(d)]
    nn = len(d)
    var = np.var(d, ddof=0)
    for k in range(1, h):
        var += 2 * np.cov(d[k:], d[:-k])[0, 1]
    return float(d.mean() / np.sqrt(var / nn))

bb = results_blocks[best].reindex(EVAL)['pred'].values.astype(float)
pn = results_blocks['Naive'].reindex(EVAL)['pred'].values.astype(float)
msk = np.isfinite(bb) & np.isfinite(pn)
dm = diebold_mariano(y_true[msk], bb[msk], pn[msk], h=HORIZON)
print(f'DM ({best} vs Naive) tai chan troi {HORIZON_NAME} = {round(dm,3)}')
print('  |DM|>1.96 => khac biet co y nghia 5%; DM>0 => Naive tot hon best.')
# Out:
# DM (Naive vs Naive) tai chan troi 1 ngay (ngay mai) = nan
#   |DM|>1.96 => khac biet co y nghia 5%; DM>0 => Naive tot hon best.
# C:\Users\quangbeone\AppData\Local\Temp\ipykernel_27552\1157482943.py:9: RuntimeWarning: invalid value encountered in scalar divide
#   return float(d.mean() / np.sqrt(var / nn))
